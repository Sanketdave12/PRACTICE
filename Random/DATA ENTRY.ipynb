# %%
import requests

# %%
url ="https://api.nytimes.com/svc/movies/v2/reviews/search.json?query=Avengers&api-key=HnrTARGbuFZAgYtibn8Ux9LTlzxUfeiN"

# %%
data = requests.get(url).json()

# %%
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'has_more': False,
#  'num_results': 5,
#  'results': [{'display_title': 'Avengers: Endgame',
#    'mpaa_rating': 'PG-13',
#    'critics_pick': 0,
#    'byline': 'A.O. SCOTT',
#    'headline': '‘Avengers: Endgame’ Review: The Real Heroes Were the Friends We Made Along the Way',
#    'summary_short': 'Iron Man, Thor, the Hulk, Captain America and other stars settle scores, tie up loose ends and take a long victory lap in the final chapter of this cycle.',
#    'publication_date': '2019-04-23',
#    'opening_date': '2019-04-26',
#    'date_updated': '2019-05-23 16:44:02',
#    'link': {'type': 'article',
#     'url': 'http://www.nytimes.com/2019/04/23/movies/avengers-endgame-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Avengers: Endgame'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
# ...

# %%
a= {'python':'PL','Father':'gvr','Frameworks':'[django,flask,pyramid]','version':'[1,2,3]'}

# %%
a
# Out:
# {'python': 'PL',
#  'Father': 'gvr',
#  'Frameworks': '[django,flask,pyramid]',
#  'version': '[1,2,3]'}

# %%
for key,items in a.items():
    print(f"{key}= {items}")
# Out:
# python= PL
# Father= gvr
# Frameworks= [django,flask,pyramid]
# version= [1,2,3]

# %%
data['results'][3]['summary_short']
# Out:
# 'Joss Whedon’s long-awaited superhero opus “The Avengers” arrives with a big cast, frequent battles and abundant banter among its characters.'

# %%
w="http://api.worldweatheronline.com/premium/v1/weather.ashx?key=5613c3e08ce145abab453014202201&q=india&format=json&num_of_days=5"

# %%
f= requests.get(w).json()

# %%
f
# Out:
# {'data': {'request': [{'type': 'City', 'query': 'New Delhi, India'}],
#   'current_condition': [{'observation_time': '05:25 AM',
#     'temp_C': '9',
#     'temp_F': '48',
#     'weatherCode': '248',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0007_fog.png'}],
#     'weatherDesc': [{'value': 'Fog'}],
#     'windspeedMiles': '6',
#     'windspeedKmph': '9',
#     'winddirDegree': '260',
#     'winddir16Point': 'W',
#     'precipMM': '0.0',
#     'precipInches': '0.0',
#     'humidity': '100',
#     'visibility': '0',
#     'visibilityMiles': '0',
#     'pressure': '1023',
#     'pressureInches': '31',
#     'cloudcover': '0',
#     'FeelsLikeC': '8',
#     'FeelsLikeF': '46',
#     'uvIndex': 2}],
#   'weather': [{'date': '2020-01-22',
#     'astronomy': [{'sunrise': '07:14 AM',
#       'sunset': '05:52 PM',
#       'moonrise': '04:58 AM',
#       'moonset': '03:35 PM',
#       'moon_phase': 'Waning Crescent',
# ...

# %%
f['data']['current_condition']
# Out:
# [{'observation_time': '05:25 AM',
#   'temp_C': '9',
#   'temp_F': '48',
#   'weatherCode': '248',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0007_fog.png'}],
#   'weatherDesc': [{'value': 'Fog'}],
#   'windspeedMiles': '6',
#   'windspeedKmph': '9',
#   'winddirDegree': '260',
#   'winddir16Point': 'W',
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '100',
#   'visibility': '0',
#   'visibilityMiles': '0',
#   'pressure': '1023',
#   'pressureInches': '31',
#   'cloudcover': '0',
#   'FeelsLikeC': '8',
#   'FeelsLikeF': '46',
#   'uvIndex': 2}]

# %%
g="http://dataservice.accuweather.com/locations/v1/countries/{5JlgEAa4QAl3dufzE0AoMTiuwJR3GbFD}"

# %%
k=requests.get(g).json()

# %%
k
# Out:
# {'fault': {'faultstring': 'Failed to resolve API Key variable request.queryparam.apikey',
#   'detail': {'errorcode': 'steps.oauth.v2.FailedToResolveAPIKey'}}}
