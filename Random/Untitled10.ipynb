# %%
import requests

# %%
url = "http://api.worldweatheronline.com/premium/v1/weather.ashx?key=5613c3e08ce145abab453014202201&q=India&format=json&num_of_days=5/5613c3e08ce145abab453014202201"

# %%
data = requests.get(url).json()

# %%
data
# Out:
# {'data': {'request': [{'type': 'City', 'query': 'New Delhi, India'}],
#   'current_condition': [{'observation_time': '06:53 AM',
#     'temp_C': '12',
#     'temp_F': '54',
#     'weatherCode': '248',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0007_fog.png'}],
#     'weatherDesc': [{'value': 'Shallow Fog'}],
#     'windspeedMiles': '7',
#     'windspeedKmph': '11',
#     'winddirDegree': '250',
#     'winddir16Point': 'WSW',
#     'precipMM': '0.0',
#     'precipInches': '0.0',
#     'humidity': '94',
#     'visibility': '1',
#     'visibilityMiles': '0',
#     'pressure': '1022',
#     'pressureInches': '31',
#     'cloudcover': '0',
#     'FeelsLikeC': '11',
#     'FeelsLikeF': '52',
#     'uvIndex': 3}],
#   'weather': [{'date': '2020-01-22',
#     'astronomy': [{'sunrise': '07:14 AM',
#       'sunset': '05:52 PM',
#       'moonrise': '04:58 AM',
#       'moonset': '03:35 PM',
#       'moon_phase': 'Waning Crescent',
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = data

# %%
a
# Out:
# {'data': {'request': [{'type': 'City', 'query': 'New Delhi, India'}],
#   'current_condition': [{'observation_time': '06:53 AM',
#     'temp_C': '12',
#     'temp_F': '54',
#     'weatherCode': '248',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0007_fog.png'}],
#     'weatherDesc': [{'value': 'Shallow Fog'}],
#     'windspeedMiles': '7',
#     'windspeedKmph': '11',
#     'winddirDegree': '250',
#     'winddir16Point': 'WSW',
#     'precipMM': '0.0',
#     'precipInches': '0.0',
#     'humidity': '94',
#     'visibility': '1',
#     'visibilityMiles': '0',
#     'pressure': '1022',
#     'pressureInches': '31',
#     'cloudcover': '0',
#     'FeelsLikeC': '11',
#     'FeelsLikeF': '52',
#     'uvIndex': 3}],
#   'weather': [{'date': '2020-01-22',
#     'astronomy': [{'sunrise': '07:14 AM',
#       'sunset': '05:52 PM',
#       'moonrise': '04:58 AM',
#       'moonset': '03:35 PM',
#       'moon_phase': 'Waning Crescent',
# ...

# %%
data = pd.DataFrame(a)

# %%
data
# Out:
#                                                                 data
# ClimateAverages    [{'month': [{'index': '1', 'name': 'January', ...
# current_condition  [{'observation_time': '06:53 AM', 'temp_C': '1...
# request              [{'type': 'City', 'query': 'New Delhi, India'}]
# weather            [{'date': '2020-01-22', 'astronomy': [{'sunris...

# %%
data.T
# Out:
#                                         ClimateAverages  \
# data  [{'month': [{'index': '1', 'name': 'January', ...
#
#                                       current_condition  \
# data  [{'observation_time': '06:53 AM', 'temp_C': '1...
#
#                                               request  \
# data  [{'type': 'City', 'query': 'New Delhi, India'}]
#
#                                                 weather
# data  [{'date': '2020-01-22', 'astronomy': [{'sunris...

# %%
data
# Out:
#                                                                 data
# ClimateAverages    [{'month': [{'index': '1', 'name': 'January', ...
# current_condition  [{'observation_time': '06:53 AM', 'temp_C': '1...
# request              [{'type': 'City', 'query': 'New Delhi, India'}]
# weather            [{'date': '2020-01-22', 'astronomy': [{'sunris...

# %%
a
# Out:
# {'data': {'request': [{'type': 'City', 'query': 'New Delhi, India'}],
#   'current_condition': [{'observation_time': '06:53 AM',
#     'temp_C': '12',
#     'temp_F': '54',
#     'weatherCode': '248',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0007_fog.png'}],
#     'weatherDesc': [{'value': 'Shallow Fog'}],
#     'windspeedMiles': '7',
#     'windspeedKmph': '11',
#     'winddirDegree': '250',
#     'winddir16Point': 'WSW',
#     'precipMM': '0.0',
#     'precipInches': '0.0',
#     'humidity': '94',
#     'visibility': '1',
#     'visibilityMiles': '0',
#     'pressure': '1022',
#     'pressureInches': '31',
#     'cloudcover': '0',
#     'FeelsLikeC': '11',
#     'FeelsLikeF': '52',
#     'uvIndex': 3}],
#   'weather': [{'date': '2020-01-22',
#     'astronomy': [{'sunrise': '07:14 AM',
#       'sunset': '05:52 PM',
#       'moonrise': '04:58 AM',
#       'moonset': '03:35 PM',
#       'moon_phase': 'Waning Crescent',
# ...

# %%
s = pd.DataFrame(a)
s.T
# Out:
#                                         ClimateAverages  \
# data  [{'month': [{'index': '1', 'name': 'January', ...
#
#                                       current_condition  \
# data  [{'observation_time': '06:53 AM', 'temp_C': '1...
#
#                                               request  \
# data  [{'type': 'City', 'query': 'New Delhi, India'}]
#
#                                                 weather
# data  [{'date': '2020-01-22', 'astronomy': [{'sunris...

# %%
d= "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&apikey=demo/42UXHCA7RNEJJLRV"

# %%
c = requests.get(d).json()

# %%
for var in c[1]:
    c['Time Series (Daily)'][var]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-d5d6b7d506b0> in <module>
# ----> 1 for var in c[1]:
#       2     c['Time Series (Daily)'][var]
#
# KeyError: 1

# %%
v = {**Meta_Data}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-078d3c4e6e62> in <module>
# ----> 1 v = {**Meta_Data}
#
# NameError: name 'Meta_Data' is not defined

# %%
import pandas as pd

# %%
a=[[[1,2,2,2,2,2,2,2,2,22,2,2,2]]]

# %%
print(*a)
# Out:
# [[1, 2, 2, 2, 2, 2, 2, 2, 2, 22, 2, 2, 2]]

# %%
x = pd.DataFrame(c)

# %%
x
# Out:
#                                                            Meta Data  \
# 1. Information     Daily Prices (open, high, low, close) and Volumes
# 2. Symbol                                                       MSFT
# 2019-08-28                                                       NaN
# 2019-08-29                                                       NaN
# 2019-08-30                                                       NaN
# 2019-09-03                                                       NaN
# 2019-09-04                                                       NaN
# 2019-09-05                                                       NaN
# 2019-09-06                                                       NaN
# 2019-09-09                                                       NaN
# 2019-09-10                                                       NaN
# 2019-09-11                                                       NaN
# 2019-09-12                                                       NaN
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/SD/Downloads/intraday_5min_MSFT.csv')

# %%
df
# Out:
#               timestamp      open      high       low     close   volume
# 0   2020-01-21 16:00:00  166.4600  166.6300  166.4500  166.5000  1277640
# 1   2020-01-21 15:55:00  166.5100  166.7700  166.4550  166.4550   566205
# 2   2020-01-21 15:50:00  166.6750  166.7250  166.5000  166.5000   567545
# 3   2020-01-21 15:45:00  166.8100  166.8100  166.6200  166.6750   260855
# 4   2020-01-21 15:40:00  166.9100  166.9200  166.7900  166.8000   231399
# 5   2020-01-21 15:35:00  166.9600  167.1000  166.8950  166.9000   233983
# 6   2020-01-21 15:30:00  166.9650  167.0300  166.9300  166.9600   149035
# 7   2020-01-21 15:25:00  166.9200  166.9800  166.8900  166.9700   160997
# 8   2020-01-21 15:20:00  166.9400  167.0000  166.9179  166.9200   119720
# 9   2020-01-21 15:15:00  166.9300  166.9900  166.9300  166.9400   160881
# 10  2020-01-21 15:10:00  166.9100  166.9300  166.8600  166.9300   137751
# 11  2020-01-21 15:05:00  166.7850  166.9600  166.7700  166.9200   180594
# ...
