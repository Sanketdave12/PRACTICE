# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.read_csv(r"C:\Users\SD\Downloads\nsedata.csv")

# %%
s
# Out:
#             SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0        20MICRONS     EQ     37.80     37.80     36.15     36.85     37.40
# 1       3IINFOTECH     EQ      4.10      4.85      4.00      4.55      4.65
# 2          3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70  13300.00
# 3          63MOONS     EQ     61.00     61.90     60.35     61.00     61.10
# 4          8KMILES     EQ    546.10    548.00    535.00    537.45    535.20
# 5         A2ZINFRA     EQ     41.30     43.00     41.25     42.00     41.90
# 6       AARTIDRUGS     EQ    539.90    539.90    520.00    521.85    522.20
# 7         AARTIIND     EQ    890.95    894.90    876.90    891.30    890.00
# 8        AARVEEDEN     EQ     58.20     61.20     57.00     59.50     59.80
# 9             ABAN     EQ    183.00    184.65    180.80    182.10    181.90
# 10             ABB     EQ   1444.00   1459.70   1424.00   1452.00   1452.50
# ...

# %%
import requests

# %%
url = "https://api.nytimes.com/svc/movies/v2/reviews/search.json?query=godfather&api-key=HnrTARGbuFZAgYtibn8Ux9LTlzxUfeiN"

# %%
data = requests.get(url).json()

# %%
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'has_more': False,
#  'num_results': 10,
#  'results': [{'display_title': 'The Black Godfather',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'BEN KENIGSBERG',
#    'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen',
#    'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.',
#    'publication_date': '2019-06-06',
#    'opening_date': '2019-06-07',
#    'date_updated': '2019-06-14 16:44:01',
#    'link': {'type': 'article',
#     'url': 'http://www.nytimes.com/2019/06/06/movies/the-black-godfather-review.html',
#     'suggested_link_text': 'Read the New York Times Review of The Black Godfather'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2019/06/05/arts/blackgodfather1/blackgodfather1-mediumThreeByTwo210.jpg',
# ...

# %%
import csv
import json

# %%
csv= (r"C:\Users\SD\Downloads\nsedata.csv")
json = 'nsedata.json'

# %%
data = {}

# %%
import csv  
import json  
  
f = open( r"C:\Users\SD\Downloads\nsedata.csv", 'r' )  
reader = csv.DictReader( f, fieldnames = ( "fieldname0","fieldname1","fieldname2","fieldname3" ))  
out = json.dumps( [ row for row in reader ] )  
print ("JSON parsed!" ) 
f = open( r"C:\Users\SD\Downloads\json.json", 'w')  
f.write(out)  
print ("JSON saved!")
# Out:
# JSON parsed!
# JSON saved!

# %%
import json

# %%
import json
s =open( r"C:\Users\SD\Downloads\nsedata.json", 'r')

# %%
print(s)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\SD\\Downloads\\nsedata.json' mode='r' encoding='cp65001'>

# %%
import json
input_file=open('json.json', 'r')
output_file=open('test.json', 'w')
json_decode=json.load(input_file)
for item in json_decode:
    my_dict={}
    my_dict['title']=item.get('labels').get('en').get('value')
    my_dict['description']=item.get('descriptions').get('en').get('value')
    my_dict['id']=item.get('id')
    print (my_dict)
back_json=json.dumps(my_dict, output_file)
output_file.write(back_json)
output_file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-68dc79bc80e0> in <module>
#       1 import json
# ----> 2 input_file=open('json.json', 'r')
#       3 output_file=open('test.json', 'w')
#       4 json_decode=json.load(input_file)
#       5 for item in json_decode:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'json.json'
