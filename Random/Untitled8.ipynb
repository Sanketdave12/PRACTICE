# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
data = sns.load_dataset('car_crashes')

# %%
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
data.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
data.shape
# Out:
# (51, 8)

# %%
data.ndim
# Out:
# 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.DataFrame({
    'SUN':[1,2,1,5,0,1],
    'MON':[1,3,2,4,5,6],
    'TUE':[1,4,3,5,6,5],
    'WED':[5,3,4,2,1,4],
    'THU':[1,3,2,4,5,6],
    'FRI':[1,3,2,4,5,6],
    'SAT':[1,3,2,4,5,6]
})

# %%
s = pd.DataFrame()

# %%
d = pd.DataFrame({
    'SUN':[1,2,1,5,0,1],
    'MON':[1,3,2,4,5,6],
    'TUE':[1,4,3,5,6,5],
    'WED':[5,3,4,2,1,4],
    'THU':[1,3,2,4,5,6],
    'FRI':[1,3,2,4,5,6],
    'SAT':[1,3,2,4,5,6]
})

# %%
d
# Out:
#    SUN  MON  TUE  WED  THU  FRI  SAT
# 0    1    1    1    5    1    1    1
# 1    2    3    4    3    3    3    3
# 2    1    2    3    4    2    2    2
# 3    5    4    5    2    4    4    4
# 4    0    5    6    1    5    5    5
# 5    1    6    5    4    6    6    6

# %%
sns.scatterplot('total', 'speeding', data=data, hue='alcohol')
plt.show()

# %%
data = sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot('total_bill','tip',data=data,hue='size')
plt.figure(figsize=(10,6))
plt.show()

# %%
sns.violinplot('sex','tip',data=data)

# %%
plt.figure(figsize=(12,6))
sns.jointplot('total_bill','tip',data=data , _origin_rc_params=)
plt.show()

# %%
sns.pairplot(data)

# %%
a
