# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from decimal import Decimal

# %%
df = pd.read_csv('E:\SD\datasets\h1b.csv')

# %%
df
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# 5                 6  CERTIFIED-WITHDRAWN
# 6                 7  CERTIFIED-WITHDRAWN
# 7                 8  CERTIFIED-WITHDRAWN
# 8                 9  CERTIFIED-WITHDRAWN
# 9                10            WITHDRAWN
# 10               11  CERTIFIED-WITHDRAWN
# 11               12  CERTIFIED-WITHDRAWN
# 12               13  CERTIFIED-WITHDRAWN
# 13               14  CERTIFIED-WITHDRAWN
# 14               15  CERTIFIED-WITHDRAWN
# 15               16  CERTIFIED-WITHDRAWN
# 16               17  CERTIFIED-WITHDRAWN
# 17               18  CERTIFIED-WITHDRAWN
# 18               19            CERTIFIED
# 19               20            CERTIFIED
# 20               21  CERTIFIED-WITHDRAWN
# 21               22  CERTIFIED-WITHDRAWN
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (2877765, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3002458 entries, 0 to 3002457
# Data columns (total 11 columns):
# Unnamed: 0            int64
# CASE_STATUS           object
# EMPLOYER_NAME         object
# SOC_NAME              object
# JOB_TITLE             object
# FULL_TIME_POSITION    object
# PREVAILING_WAGE       float64
# YEAR                  float64
# WORKSITE              object
# lon                   float64
# lat                   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 252.0+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0','lon','lat'],inplace=True,axis=1)

# %%
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE
# ...

# %%
df.head()
# Out:
#            CASE_STATUS                       SOC_NAME  \
# 0  CERTIFIED-WITHDRAWN  BIOCHEMISTS AND BIOPHYSICISTS
# 1  CERTIFIED-WITHDRAWN               CHIEF EXECUTIVES
# 2  CERTIFIED-WITHDRAWN               CHIEF EXECUTIVES
# 3  CERTIFIED-WITHDRAWN               CHIEF EXECUTIVES
# 4            WITHDRAWN               CHIEF EXECUTIVES
#
#                       JOB_TITLE FULL_TIME_POSITION  PREVAILING_WAGE    YEAR  \
# 0  POSTDOCTORAL RESEARCH FELLOW                  N          36067.0  2016.0
# 1       CHIEF OPERATING OFFICER                  Y         242674.0  2016.0
# 2         CHIEF PROCESS OFFICER                  Y         193066.0  2016.0
# 3   REGIONAL PRESIDEN, AMERICAS                  Y         220314.0  2016.0
# 4  PRESIDENT MONGOLIA AND INDIA                  Y         157518.4  2016.0
#
#                   WORKSITE
# 0      ANN ARBOR, MICHIGAN
# 1             PLANO, TEXAS
# 2  JERSEY CITY, NEW JERSEY
# 3         DENVER, COLORADO
# 4      ST. LOUIS, MISSOURI

# %%
plt.figure(figsize=(10,5))
df.JOB_TITLE.value_counts()[:15].plot(kind='bar',title='Top 15Companies to Hire')
plt.show()

# %%
cs = df.CASE_STATUS.value_counts()[:4]

# %%
cs
# Out:
# CERTIFIED              2615623
# CERTIFIED-WITHDRAWN     202659
# DENIED                   94346
# WITHDRAWN                89799
# Name: CASE_STATUS, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.pie(x=cs.values,labels=cs.index,autopct='%.1f%%',shadow=True)
plt.show()

# %%
y = df.FULL_TIME_POSITION.value_counts()

# %%
y
# Out:
# Y    2576111
# N     426332
# Name: FULL_TIME_POSITION, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.pie(x=y.values,labels=y.index,autopct='%.1f%%',shadow=True)
plt.show()

# %%
a = (df.PREVAILING_WAGE[:15])

# %%
a.max
# Out:
# <bound method Series.max of 0      36067.0
# 1     242674.0
# 2     193066.0
# 3     220314.0
# 4     157518.4
# 5     225000.0
# 6      91021.0
# 7     150000.0
# 8     127546.0
# 9     154648.0
# 10    182978.0
# 11    163717.0
# 12    203860.8
# 13    252637.0
# 14    105914.0
# Name: PREVAILING_WAGE, dtype: float64>

# %%
plt.figure(figsize=(18,10))
plt.pie(x=a.values,labels=a.index,autopct='%.1f%%',shadow=True)
plt.show()

# %%
df.nlargest(10,'PREVAILING_WAGE')
# Out:
#         CASE_STATUS                                SOC_NAME  \
# 2163248      DENIED                     Physical Therapists
# 2797982      DENIED                    Computer Programmers
# 1673867      DENIED                           Statisticians
# 1819718      DENIED       Software Developers, Applications
# 2775906      DENIED    Medical and Health Services Managers
# 1547574      DENIED               Computer Systems Analysts
# 1668384      DENIED              Life Scientists, All Other
# 1805875      DENIED  Architectural and Engineering Managers
# 2796071   WITHDRAWN                      Financial Managers
# 1698325      DENIED                     Internists, General
#
#                                      JOB_TITLE FULL_TIME_POSITION  \
# 2163248                    PHYSICAL THERAPISTS                  Y
# 2797982                     SOFTWARE DEVELOPER                  Y
# 1673867                        PROJECT MANAGER                  Y
# ...

# %%
ga = df.nlargest(10,'PREVAILING_WAGE')[['CASE_STATUS','PREVAILING_WAGE']].set_index('CASE_STATUS')

# %%
for var in ga.PREVAILING_WAGE.values:
    print(var)
# Out:
# 6997606720.0
# 1007814080.0
# 820132347.0
# 709999949.0
# 657900000.0
# 616931693.0
# 413472579.0
# 410315360.0
# 406637920.0
# 389376000.0

# %%
a.values.flatten()
# Out:
# array([6.99760672e+09, 1.00781408e+09, 8.20132347e+08, 7.09999949e+08,
#        6.57900000e+08, 6.16931693e+08, 4.13472579e+08, 4.10315360e+08,
#        4.06637920e+08, 3.89376000e+08])

# %%
plt.figure(figsize=(12,6))
plt.bar(x=ga.index,height=ga.values.flatten())
plt.show()

# %%
a.index
# Out:
# Index(['DENIED', 'DENIED', 'DENIED', 'DENIED', 'DENIED', 'DENIED', 'DENIED',
#        'DENIED', 'WITHDRAWN', 'DENIED'],
#       dtype='object', name='CASE_STATUS')
