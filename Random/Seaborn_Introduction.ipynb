# %% [markdown]
# histogram, bar chart, line plot, scatter plot, matrix

# %% [markdown]
# seborn or matplotlib
#
# python or c

# %% [markdown]
# **Select a Data Set**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from seaborn import load_dataset

# %%
tip = load_dataset('tips') # seboran data set

# %%
print(type(tip))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(tip.shape)
# Out:
# (244, 7)

# %%
print(tip.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **Data Visulation**
#
#                     quantative (continous) --> histogram
# Distribution
#
#                     categorical --> bar chart

# %% [markdown]
# **Distribution of tota_bill in tip dataset**

# %%
# matplotlib
print(tip['total_bill'].describe())
plt.figure(figsize=(10,6))
plt.hist(tip['total_bill'], bins=30, ec='cyan')
plt.xlabel("Data Points", fontsize=20, color='red')
plt.ylabel("Frequency", fontsize=20, color='red')
plt.xticks(range(0,51,2))
plt.yticks(range(0,30,2))
plt.grid()
plt.show()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(tip['total_bill'], bins=30, kde=True,rug=True,
            hist_kws = {'alpha':1, 'histtype':'step'},
            kde_kws = {'alpha':1 , 'color':'red', 'lw':3},
            ax = ax) # dist == histogram
plt.show()

# %%
sns.distplot(tip['total_bill'], bins=30, kde=False,
            hist_kws = {'alpha':1, 'ec':'cyan'}) # dist == histogram
plt.show()

# %% [markdown]
# **task** distribution plot of all numerical features

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **scatter plot** it shows releationship between two variables

# %%
c = tip['sex'].map({'Female':'red', 'Male':'blue'})
plt.figure(figsize=(10, 4))
plt.scatter('total_bill', 'tip', data=tip, color=c)
plt.grid(color='#123456')
plt.xlabel('Total Bill', color='green', fontsize=20)
plt.ylabel('Tip', color='green', fontsize=20)
plt.xticks(range(0,55,5))
plt.yticks(range(12))
plt.show()

# %%
# !python --version # update anaconda --> uinstall --> new version install

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(12,8))
sns.scatterplot('total_bill', 'tip', data=tip, hue='sex', style='day', size='smoker')
plt.show()

# %%
sns.jointplot("total_bill", "tip", data=tip,)
plt.show()

# %%
sns.jointplot("total_bill", "tip", kind='hex', data=tip, color='k')
plt.show()

# %%
sns.jointplot("total_bill", "tip", kind='kde', data=tip, color='r')
plt.show()

# %%
sns.jointplot("total_bill", "tip", kind='reg', data=tip)
plt.show()

# %% [markdown]
# ### pair_plot, boxplot, violin, swarmplot, count

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# BAR --> label, data

# %%
s = tip['sex'].value_counts()

# %%
s
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
label = list(s.index)
value = s.values

# %%
label
# Out:
# ['Male', 'Female']

# %%
value
# Out:
# array([157,  87], dtype=int64)

# %%
plt.bar(label, value, color='r')
plt.show()

# %%
s = tip.groupby('sex').agg({'smoker':pd.value_counts})

# %%
s
# Out:
#             smoker
# sex
# Male   No       97
#        Yes      60
# Female No       54
#        Yes      33

# %%
ms = s.iloc[:2]
fs = s.iloc[2:]

# %%
ms
# Out:
#           smoker
# sex
# Male No       97
#      Yes      60

# %%
fs
# Out:
#             smoker
# sex
# Female No       54
#        Yes      33

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot('sex', data=tip)
plt.show()

# %%
sns.countplot('sex', data=tip, hue='smoker')
plt.show()

# %%
diamond = sns.load_dataset('diamonds')

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamond.shape
# Out:
# (53940, 10)

# %%
plt.figure(figsize=(12,6))
sns.scatterplot('carat', 'price', data=diamond, hue='cut', style='cut') # categorical
plt.show()

# %% [markdown]
# Data Analysis --> Sample --> statistics ( descrptive stats)
#
# Data Analyst --> population --> sample to population generalization --> parameters  (infertial stats)

# %%
d = diamond.sample(10000)

# %%
plt.figure(figsize=(12,6))
sns.scatterplot('carat', 'price', data=d, hue='cut', style='clarity', size='color') # categorical
plt.show()

# %% [markdown]
# Categorical data

# %%
sns.countplot('cut', data=diamond)
plt.show()

# %% [markdown]
# ## box plot

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot('sex', 'total_bill', data=tip) # box --> continous
plt.show()

# %%
sns.boxenplot('cut', 'price', data=diamond)
plt.show()

# %%
sns.boxplot('cut', 'price', data=diamond)
plt.show()

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
plt.figure(figsize=(12,6))
sns.violinplot('cut', 'price', data=diamond)
plt.show()

# %%
from seaborn import get_dataset_names

# %%
get_dataset_names()
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.rcParams['figure.figsize'] = (12, 6)

# %%
ax = sns.violinplot('day', 'total_bill', hue='sex', data=tip)

# %%
ax = sns.violinplot('day', 'total_bill', hue='sex', data=tip, split=True)

# %%
ax = sns.swarmplot('day', 'total_bill', hue='sex', data=tip)

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(y='sex', hue='smoker', data=tip)
plt.show()

# %%
ax = sns.barplot(x='sex', y='total_bill', data=tip, estimator=np.median)

# %%
ax = sns.barplot(x='total_bill', y='sex',hue='smoker', dodge=False, data=tip, estimator=np.median,
                alpha=0.1)

# %%
ax = sns.barplot(x='total_bill', y='sex',hue='smoker', data=tip, estimator=np.median,
            palette='rainbow' )

# %%
flight = sns.load_dataset('flights')

# %%
flight.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
plt.bar('month', 'passengers', data=flight, )
plt.show()

# %%
sns.barplot('month', 'passengers', data=flight, palette='rainbow', errwidth=0)
plt.show()

# %%
flight.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %% [markdown]
# long to wide conversion

# %%
newdf = flight.pivot_table(columns='year', index='month', values='passengers')

# %%
newdf.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
ax = sns.heatmap(newdf, cmap='coolwarm')

# %% [markdown]
# Monday --> saturday and sunday is off ( introduction machine )
