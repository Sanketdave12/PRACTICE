# %%
import pandas as pd
import numpy as np

# %%
import json
import csv

# %%
s = pd.read_csv(r"F:\sd12\nsedata.csv").to_json(r"F:\sd12\sd.json")

# %%
d = pd.read_json(r"F:\sd12\sd.json")

# %%
d
# Out:
#             SYMBOL SERIES     OPEN     HIGH      LOW    CLOSE     LAST  \
# 0        20MICRONS     EQ    37.80    37.80    36.15    36.85    37.40
# 1       3IINFOTECH     EQ     4.10     4.85     4.00     4.55     4.65
# 10             ABB     EQ  1444.00  1459.70  1424.00  1452.00  1452.50
# 100      ARSSINFRA     EQ    64.70    65.95    64.00    64.80    64.50
# 1000          MTNL     EQ    20.45    20.70    20.30    20.35    20.45
# 10000   PROZONINTU     EQ    33.75    35.00    33.75    34.45    34.50
# 100000        NTPC     N7    12.78    12.95    12.78    12.82    12.82
# 100001        NTPC     NB  1125.00  1125.00  1105.10  1105.10  1105.10
# 100002     NUCLEUS     EQ   249.55   249.60   242.10   242.40   242.15
# 100003       NUTEK     EQ     0.75     0.75     0.65     0.70     0.70
# 100004    NV20IWIN     EQ    40.01    40.01    40.01    40.01    40.01
# 100005  OBEROIRLTY     EQ   360.20   372.90   360.20   370.90   371.00
# ...
